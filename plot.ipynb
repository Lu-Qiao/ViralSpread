# %%
# Plot Number of Cells vs. Time
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# read data into dataframe
df = pd.read_csv('ViralSpread.exe_assign_no_treatment.out.csv')
# plot data
plt.plot(df['Time (day)'], df['Number of normal cells'], label='Uninfected')
plt.plot(df['Time (day)'], df['Number of target cells'], label='Infected')
plt.plot(df['Time (day)'], df['Number of infectious cells'], label='Infectious')
plt.plot(df['Time (day)'], df['Number of dead cells'], label='Dead')
# setup plot
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams.update({'font.size': 15})
plt.title('Number of Cells vs. Time')
plt.xlabel('Time (days)')
plt.ylabel('Number of cells')
plt.legend()
plt.savefig('ViralSpread.exe_assign_no_treatment.out.jpg', bbox_inches='tight', dpi=500)

# %%
# Plot Number of Cells vs. Block Cell Effectiveness (30 days)
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# read data into dataframe
df = pd.read_csv('blockcell_effectiveness.csv')
# plot data
plt.plot(df['Effectiveness'], df['Number of normal cells'], label='Uninfected')
plt.plot(df['Effectiveness'], df['Number of target cells'], label='Infected')
plt.plot(df['Effectiveness'], df['Number of infectious cells'], label='Infectious')
plt.plot(df['Effectiveness'], df['Number of dead cells'], label='Dead')
# setup plot
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams.update({'font.size': 15})
plt.title('Number of Cells vs. Block Cell Effectiveness (30 days)')
plt.xlabel('Block Cell Therapy Effectiveness')
plt.ylabel('Number of cells')
plt.legend()
plt.savefig('blockcell_effectiveness.jpg',bbox_inches='tight', dpi=500)

# %%
# Plot Number of Cells vs. Block Virus Effectiveness (30 days)
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# read data into dataframe
df = pd.read_csv('blockvirus_effectiveness.csv')
# plot data
plt.plot(df['Effectiveness'], df['Number of normal cells'], label='Uninfected')
plt.plot(df['Effectiveness'], df['Number of target cells'], label='Infected')
plt.plot(df['Effectiveness'], df['Number of infectious cells'], label='Infectious')
plt.plot(df['Effectiveness'], df['Number of dead cells'], label='Dead')
# setup plot
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams.update({'font.size': 15})
plt.title('Number of Cells vs. Block Virus Effectiveness (30 days)')
plt.xlabel('Block Virus Therapy Effectiveness')
plt.ylabel('Number of cells')
plt.legend()
plt.savefig('blockvirus_effectiveness.jpg',bbox_inches='tight', dpi=500)

# %%
# Plot Number of Cells vs. Block Both Effectiveness (30 days)
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# read data into dataframe
df = pd.read_csv('blockboth_effectiveness.csv')
# plot data
plt.plot(df['Effectiveness'], df['Number of normal cells'], label='Uninfected')
plt.plot(df['Effectiveness'], df['Number of target cells'], label='Infected')
plt.plot(df['Effectiveness'], df['Number of infectious cells'], label='Infectious')
plt.plot(df['Effectiveness'], df['Number of dead cells'], label='Dead')
# setup plot
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams.update({'font.size': 15})
plt.title('Number of Cells vs. Block Both Effectiveness (30 days)')
plt.xlabel('Block Virus Therapy Effectiveness')
plt.ylabel('Number of cells')
plt.legend()
plt.savefig('blockboth_effectiveness.jpg',bbox_inches='tight', dpi=500)
